# %% [markdown]
# ## Giancarlo Palumbo
# ## Data Science Programming
# ## Professor Binowski
# ### 3/14/2023
# ### cleaning data to more easily read and make decisions for the IT department based off of these findings

# %%
import pandas as pd

# %%
datafile = "CCM Computing Entry Survey - Fall 2022(1).csv"
df = pd.read_csv(datafile, index_col=2,parse_dates=True)
df
# Out:
#                                                                      Timestamp  \
# How did you hear about County College of Morris...
# Yes                                                 2022/09/26 12:13:34 PM EST
# No                                                   2022/09/26 1:36:22 PM EST
# No                                                   2022/09/26 1:37:38 PM EST
# No                                                   2022/09/26 1:39:43 PM EST
# Yes                                                  2022/09/26 1:40:07 PM EST
# ...                                                                        ...
# Yes                                                  2022/10/21 4:19:00 PM EST
# No                                                  2022/10/24 11:25:45 AM EST
# Don't recall                                         2022/10/25 2:00:22 PM EST
# No                                                   2022/11/22 9:14:03 PM EST
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
#        'How did you hear about County College of Morris? [Television]',
#        'How did you hear about County College of Morris? [Radio]',
# ...

# %%
df['What degree program are you currently enrolled in?'].value_counts()
# Out:
# Computer Science                                                                                                                                           83
# Information Technology                                                                                                                                     43
# ShareTime CSIP Program                                                                                                                                     10
# Undecided                                                                                                                                                   9
# CIS Game Development Option                                                                                                                                 9
# Digital Media Technology                                                                                                                                    5
# ...

# %% [markdown]
# ### Below, grouping all majors that include the variation of the word engingeering, into one 'Engineering' block. Reduces redundancies and cleans the data a little bit

# %%
df.loc[df['What degree program are you currently enrolled in?'].str.contains('Engineering',), 'What degree program are you currently enrolled in?'] = 'Engineering'
df.loc[df['What degree program are you currently enrolled in?'].str.contains('Business'), 'What degree program are you currently enrolled in?'] = 'Business'
df.loc[df['What degree program are you currently enrolled in?'].str.contains('engineering'), 'What degree program are you currently enrolled in?'] = 'Engineering'

# %%
df['Race'].value_counts()
# Out:
# White/Caucasian                                                                                                                                         92
# Hispanic or Latino                                                                                                                                      44
# Asian                                                                                                                                                   32
# Hispanic or Latino;White/Caucasian                                                                                                                      18
# Choose not to reply                                                                                                                                     12
# Multi-Racial                                                                                                                                             9
# ...

# %% [markdown]
# ### Below, drops unwanted columns from the data that would be of little value

# %%
df.drop(axis=1, columns=['To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]'], inplace=True)

# %%
df.drop(axis=1, columns=['Timestamp'], inplace=True)

# %% [markdown]
# ### Below, an example of if you would want to group a certain amount of columns together
# #### Unsure of why that extra column is put into the mix

# %%
ragdf = df[["Race", "Gender", "Age "]]
ragdf
# Out:
#                                                                                   Race  \
# How did you hear about County College of Morris...
# Yes                                                                    White/Caucasian
# No                                                                     White/Caucasian
# No                                                                     White/Caucasian
# No                                                                               Asian
# Yes                                                                    White/Caucasian
# ...                                                                                ...
# Yes                                                 Hispanic or Latino;White/Caucasian
# No                                                                               Asian
# Don't recall                                                           White/Caucasian
# ...

# %% [markdown]
# ### Below, count of each tally of gender if you wanted to easily calculate the amounts

# %%
df['Gender'].value_counts()
# Out:
# Man                  163
# Woman                 42
# Prefer not to say      7
# I do not identify      3
# Non-binary             3
# Name: Gender, dtype: int64

# %% [markdown]
# ### Below, if you want to look for a keyword in the data and the answers for that keyword

# %%
df[df.Race.str.contains('Asian')]
# Out:
#                                                                                           Course  \
# How did you hear about County College of Morris...
# No                                                                    CMP 128 Computer Science I
# No                                                                    CMP 128 Computer Science I
# No                                                                    CMP 128 Computer Science I
# No                                                                    CMP 128 Computer Science I
# Yes                                                                   CMP 128 Computer Science I
# Don't recall                                                          CMP 128 Computer Science I
# No                                                                    CMP 128 Computer Science I
# No                                                                    CMP 128 Computer Science I
# ...

# %% [markdown]
# ### Below, a long list of renaming columns to clean the data

# %%
df.rename(
    columns=({ 'Race/ethnicity': 'Race'}), 
    inplace=True,
)

# %%
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]': 'infosource_HS guidance counselor'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]': 'infosource_HS teacher'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]': 'infosource_CCM Info Tech Website'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]': 'infosource_CCM admissions'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]': 'infosource_CCM advisor/counselor'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [Employer]': 'infosource_Employer'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]': 'infosource_CCM workforce development'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]': 'infosource_NJ Workforce development'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Did you receive information about the CCM computing programs from any of the following sources? [Other]': 'infosource_other'}), 
    inplace=True,
)

# %%
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'Small class sizes'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]': 'Extra-curricular opportunities'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'Accepted my transfer credits'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'Negative experience at another college'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'NJ Stars Program'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'Ability to trasnfer credits to a 4-year school'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'Get college credit while in HS'}), 
    inplace=True,
)

# %%
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]': 'Open House'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]': 'Instant Decision Day'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]': 'On-Campus Info session'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]': 'Titans Tuesday'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]': 'Women Who Dare'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]': 'College Fair'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]': 'HS Sharetime'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]': 'Challenger Program'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]': 'CyberSecurity Protection Program'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]': 'Info session at HS'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]': 'Campus visit with HS'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]': 'Individual Campus Visit'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]': 'Workforce Development class'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]': 'Corporate Training'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]': 'Teen Arts Festival'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]': 'Summer camp at CCM'}), 
    inplace=True,
)
df.rename(
    columns=({ 'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]': 'Hour of Code'}), 
    inplace=True,
)

# %%
df.rename(
    columns=({ 'Which course are you enrolled in?': 'Course'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Social Media]': 'Social Media'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [CCM Alumni]': 'CCM Alumni'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Community Event]': 'Community Event'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Family member or friend]': 'Family member or friend'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Current CCM student]': 'Current CCM Student'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [High School Teacher]': 'High School Teacher'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [High School Counselor]': 'High School Counselor'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [In-app advertisement]': 'In-App advertisement'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Employer]': 'Employer'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Billboard]': 'Billboard'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Television]': 'Television'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Radio]': 'Radio'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Home mailer]': 'Home mailer'}), 
    inplace=True,
)
df.rename(
    columns=({ 'How did you hear about County College of Morris? [Other]': 'Other'}), 
    inplace=True,
)

# %%
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'Affordable Cost'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'Location/convenience'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'Choice of programs'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'Online offerings'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'Family/friend referral'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'Faculty/staff'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'College reputation'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'Financial Aid'}), 
    inplace=True,
)
df.rename(
    columns=({ 'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'Scholarships'}), 
    inplace=True,
)

# %% [markdown]
# ### Below, more dropping of certain unwanted columns to organize the data

# %%
df.drop(axis=1, columns=['What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]',
       'What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]',
       'What motivated you to seek a computing degree/certificate at CCM?  [Career Change]',
       'What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]',
       'What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]',
       'What motivated you to seek a computing degree/certificate at CCM?  [Relocation]',
       'What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]',
       'What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]',
       'What motivated you to seek a computing degree/certificate at CCM?  [Financial]',
       'What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]'], inplace=True)

# %% [markdown]
# ### Below, changing all answers of race that include the word 'Multi-Racial' into one category called 'Multi-Racial', This sorts and cleans the data

# %%
df.loc[df['Race'].str.contains('Multi-Racial'), 'Race'] = 'Multi-Racial'

# %% [markdown]
# ### Updated column list

# %%
df
# Out:
#                                                                                           Course  \
# How did you hear about County College of Morris...
# Yes                                                                   CMP 128 Computer Science I
# No                                                                                           NaN
# No                                                                    CMP 128 Computer Science I
# No                                                                    CMP 128 Computer Science I
# Yes                                                                   CMP 128 Computer Science I
# ...                                                                                          ...
# Yes                                                 CMP 131 Fundamentals of Programming (Python)
# No                                                                    CMP 128 Computer Science I
# ...

# %%
#df.to_csv('Second Cleaned Data Exploration')

# %% [markdown]
# ### A family member or friend is the best way for a student to hear about CCM

# %%
#s= df[df == 'Yes'].count()
#s
# Out:
# Course                                                                                                                                                   0
# Social Media                                                                                                                                            35
# Community Event                                                                                                                                         29
# Family member or friend                                                                                                                                157
# Current CCM Student                                                                                                                                     87
#                                                                                                                                                       ...
# ...

# %% [markdown]
# ### Majority of students that enrolled in these classes were already a computing major, but 35% of students were second choice/non major students

# %%
#df['Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.'].value_counts()
# Out:
# First Choice                                                                         101
# Engineering                                                                           15
# Business                                                                              13
# LIberal Arts                                                                           7
# Science                                                                                4
# Nursing                                                                                2
# Criminal Justice                                                                       2
# Game Development                                                                       1
# Computer Science                                                                       1
# Architecture Program                                                                   1
# ...

# %%
#55+101
# Out:
# 156

# %%
#55/156
# Out:
# 0.3525641025641026

# %%
#df['On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?'].value_counts()
# Out:
# 4.0    19
# 3.0    19
# 5.0    10
# 2.0     6
# 1.0     4
# Name: On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?, dtype: int64

# %%
#import matplotlib.pyplot as plt

# %%
#29/58
# Out:
# 0.5

# %%
#48/58
# Out:
# 0.8275862068965517

# %% [markdown]
# ### 50% of students gave a 4 and 5
# ### 83% of students gave a 3 and up
# ### Most students would be interested in taking another computing class

# %% [markdown]
# ### Plot of total students which would take another computing class,  most would take another class

# %%
#ages = df['On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?']

#plt.hist(ages, bins=30)
#plt.xlabel('Number')
#plt.ylabel('Total')
#plt.show()

# %% [markdown]
# ### An idea for recruiting more students would be to show them that it may seem daunting at first, but after other students have taken a computing class they learn that they like it.

# %%
df.to_csv('Project #2: Data Exploration and Cleaning')
